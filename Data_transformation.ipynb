# %%
import pandas as pd
import numpy as np

# %%
pd.read_csv(r'.\data\recipes.csv',nrows = 2, names)
# Out:
#    African        chicken cinnamon soy_sauce     onion    ginger Unnamed: 6  \
# 0  African  cane_molasses   ginger     cumin    garlic  tamarind      bread
# 1  African         butter   pepper     onion  cardamom   cayenne     ginger
#
#        Unnamed: 7 Unnamed: 8 Unnamed: 9     ...      Unnamed: 23 Unnamed: 24  \
# 0       coriander    vinegar      onion     ...              NaN         NaN
# 1  cottage_cheese     garlic   brassica     ...              NaN         NaN
#
#   Unnamed: 25 Unnamed: 26 Unnamed: 27 Unnamed: 28 Unnamed: 29  Unnamed: 30  \
# 0         NaN         NaN         NaN         NaN         NaN          NaN
# 1         NaN         NaN         NaN         NaN         NaN          NaN
#
#    Unnamed: 31  Unnamed: 32
# 0          NaN          NaN
# 1          NaN          NaN
#
# [2 rows x 33 columns]
